# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
# transction are of almost 2 days
#

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#  checking missing values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# disturbution of legit transaction and fraudent transaction
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# this dataset is highly unbalanced
# 0 --> normal transaction
# 1 --> fraudlent transaction

# %%
# seperating data for analysis
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
print(legit.shape)
legit.head()
# Out:
# (284315, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(fraud.shape)
fraud.head()
# Out:
# (492, 31)
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# camparre value for both the transaction
df.groupby('Class').mean()
# find the average of all the columns
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [raw]
# under sampling
# build a sample dataset containg similar distrubution of normal transactions and fraudeltn transactions
# number of fraudelent transactions -> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# concatinating two dataframes

# %%
new_dataset = pd.concat([legit_sample, fraud], axis = 0)

# %%
new_dataset = pd.concat([legit_sample,fraud],axis = 0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 275204  166421.0 -0.003730  0.791219  0.295919 -0.564461  0.450506 -1.170352
# 132242   79914.0 -1.631201  1.030757 -0.280810 -1.059740  1.578021  3.837224
# 120831   75975.0 -0.328785  0.634691  2.266077  0.687559 -0.564914 -0.176655
# 253588  156323.0 -1.434147  0.893324  0.129453  0.665993  0.037805  1.002263
# 272960  165350.0 -0.890898  1.444564 -0.850808  0.211363  0.834717 -0.584116
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 275204  0.970832 -0.199764 -0.031308  ... -0.254352 -0.578659  0.088050
# 132242 -0.692754  1.561826  0.614752  ...  0.001813  0.264864 -0.200657
# 120831  0.062697  0.161916  0.274574  ...  0.196155  0.676462 -0.215619
# 253588 -0.106849  0.977741 -1.345180  ... -0.373956 -1.389193  0.158645
# 272960  0.940228  0.092540 -0.495475  ...  0.264104  0.534772 -0.170024
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      97235.020325  0.083412 -0.144611  0.032153  0.018624  0.003912
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.000659  0.000717  0.002245 -0.021872  ...  0.053072 -0.015906
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.035884 -0.035223  0.004702 -0.031654  0.028956 -0.007308 -0.019062
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0      106.608272
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# splitting the data into features & target

# %%
X = new_dataset.drop(columns = 'Class',axis = 1)

# %%
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 275204  166421.0 -0.003730  0.791219  0.295919 -0.564461  0.450506 -1.170352
# 132242   79914.0 -1.631201  1.030757 -0.280810 -1.059740  1.578021  3.837224
# 120831   75975.0 -0.328785  0.634691  2.266077  0.687559 -0.564914 -0.176655
# 253588  156323.0 -1.434147  0.893324  0.129453  0.665993  0.037805  1.002263
# 272960  165350.0 -0.890898  1.444564 -0.850808  0.211363  0.834717 -0.584116
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 275204    0
# 132242    0
# 120831    0
# 253588    0
# 272960    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# split the data into training & testing Data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size = 0.2,stratify=Y, random_state = 2)

# %%
X.shape,X_train.shape, X_test.shape,X_test.shape
# Out:
# ((984, 30), (787, 30), (197, 30), (197, 30))

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
# logistic regression
logistic_model = LogisticRegression()

# %%
# traing thelogistic resgression model
logistic_model.fit(X_train, Y_train)
# Out:
# C:\Users\Rutuja\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# model Evalution

# %% [markdown]
# Accuracy score

# %%
# accuracuy on training data

# %%
X_train_prediction =logistic_model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy on trainig data",training_data_accuracy)
# Out:
# Accuracy on trainig data 0.9440914866581956

# %%
# accurarcy on test data
X_test_prediction = logistic_model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on test data : ',test_data_accuracy)
# Out:
# Accuracy score on test data :  0.9390862944162437

# %% [markdown]
# # model is train using decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_model = DecisionTreeClassifier(criterion="gini", max_depth=4, random_state=42)

# %%
tree_model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
X_train_prediction = tree_model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy on trainig data",training_data_accuracy)
# Out:
# Accuracy on trainig data 0.9644218551461246

# %%
# accurarcy on test data
X_test_prediction = tree_model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on test data : ',test_data_accuracy)
# Out:
# Accuracy score on test data :  0.9187817258883249

# %% [markdown]
# # random forest algorothm

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
X_train_prediction = rf_model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy on trainig data",training_data_accuracy)
# Out:
# Accuracy on trainig data 1.0

# %%
# accurarcy on test data
X_test_prediction = rf_model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on test data : ',test_data_accuracy)
# Out:
# Accuracy score on test data :  0.9238578680203046

# %% [markdown]
# # XGBOOST

# %%
import xgboost as xgb
from xgboost import XGBClassifier

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42, stratify=Y)

# %%
# Create and train model
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# %%
xgb_model.fit(X_train, Y_train)
# Out:
# C:\Users\Rutuja\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\training.py:183: UserWarning: [00:10:00] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
X_train_prediction = xgb_model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy on trainig data",training_data_accuracy)
# Out:
# Accuracy on trainig data 1.0

# %%
# accurarcy on test data
X_test_prediction = xgb_model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on test data : ',test_data_accuracy)
# Out:
# Accuracy score on test data :  0.9746192893401016

# %% [markdown]
# # only checking accuracy score is not sufficient so

# %% [markdown]
# ## precison recall f1 score roc - auc must nedd to check

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, classification_report , confusion_matrix

# %% [markdown]
# #applying for each model precison recall f1 score roc curve

# %%
models = {
    "Logistic Regressiom": logistic_model,
    "Decision Tree": tree_model,
    "Random Forest": rf_model,
    "XGBoost": xgb_model
}

# %% [markdown]
# for name, model in models.items():
#     Y_pred = model.predict(X_test)
#     Y_pred_prob = model.predict_proba(X_test)[:,1]
#
#     print(f"\n{name} Results:")
#     print("Precision:", precision_score(Y_test, Y_pred))
#     print("Recall:", recall_score(Y_test, Y_pred))
#     print("F1-score:", f1_score(Y_test, Y_pred))
#     print("ROC-AUC:", roc_auc_score(Y_test, Y_pred_prob))

# %% [markdown]
# # Deploy With FAST API

# %% [markdown]
# # saving Model

# %%
import joblib
from sklearn.ensemble import RandomForestClassifier

# %%
# Train best model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
joblib.dump(rf_model, "fraud_model1.pkl")
# Out:
# ['fraud_model1.pkl']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Rutuja\RESUME+P

# %%
# joblib.dump(df, 'fraud_model.pkl')
